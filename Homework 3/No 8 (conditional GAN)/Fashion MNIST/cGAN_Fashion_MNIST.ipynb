# %%
import os, time, itertools, imageio, pickle
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# leaky_relu
def lrelu(X, leak=0.2):
    f1 = 0.5 * (1 + leak)
    f2 = 0.5 * (1 - leak)
    return f1 * X + f2 * tf.abs(X)

# G(z)
def generator(x, y, isTrain=True, reuse=False):
    with tf.variable_scope('generator', reuse=reuse):
        w_init = tf.contrib.layers.xavier_initializer()

        cat1 = tf.concat([x, y], 1)

        dense1 = tf.layers.dense(cat1, 128, kernel_initializer=w_init)
        relu1 = tf.nn.relu(dense1)

        dense2 = tf.layers.dense(relu1, 784, kernel_initializer=w_init)
        o = tf.nn.tanh(dense2)

        return o

# D(x)
def discriminator(x, y, isTrain=True, reuse=False):
    with tf.variable_scope('discriminator', reuse=reuse):
        w_init = tf.contrib.layers.xavier_initializer()

        cat1 = tf.concat([x, y], 1)

        dense1 = tf.layers.dense(cat1, 128, kernel_initializer=w_init)
        lrelu1 = lrelu(dense1, 0.2)

        dense2 = tf.layers.dense(lrelu1, 1, kernel_initializer=w_init)
        o = tf.nn.sigmoid(dense2)

        return o, dense2

# label preprocess
onehot = np.eye(10)

temp_z_ = np.random.normal(0, 1, (10, 100))
fixed_z_ = temp_z_
fixed_y_ = np.zeros((10, 1))

for i in range(9):
    fixed_z_ = np.concatenate([fixed_z_, temp_z_], 0)
    temp = np.ones((10,1)) + i
    fixed_y_ = np.concatenate([fixed_y_, temp], 0)

fixed_y_ = onehot[fixed_y_.astype(np.int32)].squeeze()
def show_result(num_epoch, show = False, save = False, path = 'D:/David/Tasks/Machine Learning/Prof Dae-Ki Kang Class/Homework/HW3/No 8/Fashion MNIST/result.png'):
    test_images = sess.run(G_z, {z: fixed_z_, y: fixed_y_, isTrain: False})

    size_figure_grid = 10
    fig, ax = plt.subplots(size_figure_grid, size_figure_grid, figsize=(5, 5))
    for i, j in itertools.product(range(size_figure_grid), range(size_figure_grid)):
        ax[i, j].get_xaxis().set_visible(False)
        ax[i, j].get_yaxis().set_visible(False)

    for k in range(size_figure_grid*size_figure_grid):
        i = k // size_figure_grid
        j = k % size_figure_grid
        ax[i, j].cla()
        ax[i, j].imshow(np.reshape(test_images[k], (28, 28)), cmap='gray')

    label = 'Epoch {0}'.format(num_epoch)
    fig.text(0.5, 0.04, label, ha='center')

    if save:
        plt.savefig(path)

    if show:
        plt.show()
    else:
        plt.close()

def show_train_hist(hist, show = False, save = False, path = 'D:/David/Tasks/Machine Learning/Prof Dae-Ki Kang Class/Homework/HW3/No 8/Fashion MNIST/Train_hist.png'):
    x = range(len(hist['D_losses']))

    y1 = hist['D_losses']
    y2 = hist['G_losses']

    plt.plot(x, y1, label='D_loss')
    plt.plot(x, y2, label='G_loss')

    plt.xlabel('Epoch')
    plt.ylabel('Loss')

    plt.legend(loc=4)
    plt.grid(True)
    plt.tight_layout()

    if save:
        plt.savefig(path)

    if show:
        plt.show()
    else:
        plt.close()

# training parameters
batch_size = 100
lr = 0.0002
train_epoch = 100

# load MNIST
mnist = input_data.read_data_sets('data/fashion', one_hot=True)
train_set = (mnist.train.images - 0.5) / 0.5  # normalization; range: -1 ~ 1
train_label = mnist.train.labels

# variables : input
x = tf.placeholder(tf.float32, shape=(None, 784))
y = tf.placeholder(tf.float32, shape=(None, 10))
z = tf.placeholder(tf.float32, shape=(None, 100))
isTrain = tf.placeholder(dtype=tf.bool)

# networks : generator
G_z = generator(z, y, isTrain)

# networks : discriminator
D_real, D_real_logits = discriminator(x, y, isTrain)
D_fake, D_fake_logits = discriminator(G_z, y, isTrain, reuse=True)

# loss for each network
D_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_real_logits, labels=tf.ones([batch_size, 1])))
D_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_fake_logits, labels=tf.zeros([batch_size, 1])))
D_loss = D_loss_real + D_loss_fake
G_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_fake_logits, labels=tf.ones([batch_size, 1])))

# trainable variables for each network
T_vars = tf.trainable_variables()
D_vars = [var for var in T_vars if var.name.startswith('discriminator')]
G_vars = [var for var in T_vars if var.name.startswith('generator')]

# optimizer for each network
with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
    D_optim = tf.train.AdamOptimizer(lr, beta1=0.5).minimize(D_loss, var_list=D_vars)
    G_optim = tf.train.AdamOptimizer(lr, beta1=0.5).minimize(G_loss, var_list=G_vars)

# open session and initialize all variables
sess = tf.InteractiveSession()
tf.global_variables_initializer().run()

# results save folder
root = 'D:/David/Tasks/Machine Learning/Prof Dae-Ki Kang Class/Homework/HW3/No 8/Fashion MNIST/Fashion_MNIST_cGAN_results/'
model = 'Fashion_MNIST_cGAN_'
if not os.path.isdir(root):
    os.mkdir(root)
if not os.path.isdir(root + 'Fixed_results'):
    os.mkdir(root + 'Fixed_results')

train_hist = {}
train_hist['D_losses'] = []
train_hist['G_losses'] = []
train_hist['per_epoch_ptimes'] = []
train_hist['total_ptime'] = []

# training-loop
np.random.seed(int(time.time()))
print('training start!')
start_time = time.time()
for epoch in range(train_epoch):
    G_losses = []
    D_losses = []
    epoch_start_time = time.time()
    for iter in range(len(train_set) // batch_size):
        # update discriminator
        x_ = train_set[iter * batch_size:(iter + 1) * batch_size]
        y_ = train_label[iter * batch_size:(iter + 1) * batch_size]

        z_ = np.random.normal(0, 1, (batch_size, 100))

        loss_d_, _ = sess.run([D_loss, D_optim], {x: x_, y: y_, z: z_, isTrain: True})
        D_losses.append(loss_d_)

        # update generator
        z_ = np.random.normal(0, 1, (batch_size, 100))
        y_ = np.random.randint(0, 9, (batch_size, 1))
        y_ = onehot[y_.astype(np.int32)].squeeze()
        loss_g_, _ = sess.run([G_loss, G_optim], {z: z_, x: x_, y: y_, isTrain: True})
        G_losses.append(loss_g_)

    epoch_end_time = time.time()
    per_epoch_ptime = epoch_end_time - epoch_start_time
    print('[%d/%d] - ptime: %.2f loss_d: %.3f, loss_g: %.3f' % ((epoch + 1), train_epoch, per_epoch_ptime, np.mean(D_losses), np.mean(G_losses)))
    fixed_p = root + 'Fixed_results/' + model + str(epoch + 1) + '.png'
    show_result((epoch + 1), save=True, path=fixed_p)
    train_hist['D_losses'].append(np.mean(D_losses))
    train_hist['G_losses'].append(np.mean(G_losses))
    train_hist['per_epoch_ptimes'].append(per_epoch_ptime)

end_time = time.time()
total_ptime = end_time - start_time
train_hist['total_ptime'].append(total_ptime)

print('Avg per epoch ptime: %.2f, total %d epochs ptime: %.2f' % (np.mean(train_hist['per_epoch_ptimes']), train_epoch, total_ptime))
print("Training finish!... save training results")
with open(root + model + 'train_hist.pkl', 'wb') as f:
    pickle.dump(train_hist, f)

show_train_hist(train_hist, save=True, path=root + model + 'train_hist.png')

images = []
for e in range(train_epoch):
    img_name = root + 'Fixed_results/' + model + str(e + 1) + '.png'
    images.append(imageio.imread(img_name))
imageio.mimsave(root + model + 'generation_animation.gif', images, fps=5)

saver = tf.train.Saver()
saver.save(sess, 'D:/David/Tasks/Machine Learning/Prof Dae-Ki Kang Class/Homework/HW3/No 8/Fashion MNIST/Model/Fashion_MNIST_cGAN_model')

sess.close()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1212 14:33:36.548326  3456 deprecation.py:323] From <ipython-input-1-ac654c5da435>:112: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# W1212 14:33:36.552324  3456 deprecation.py:323] From C:\Users\Laboratory\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# W1212 14:33:36.553325  3456 deprecation.py:323] From C:\Users\Laboratory\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/fashion\train-images-idx3-ubyte.gz
# W1212 14:33:37.103980  3456 deprecation.py:323] From C:\Users\Laboratory\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# W1212 14:33:37.130967  3456 deprecation.py:323] From C:\Users\Laboratory\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# W1212 14:33:37.233901  3456 deprecation.py:323] From C:\Users\Laboratory\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# Extracting data/fashion\train-labels-idx1-ubyte.gz
# Extracting data/fashion\t10k-images-idx3-ubyte.gz
# Extracting data/fashion\t10k-labels-idx1-ubyte.gz
# W1212 14:33:37.900487  3456 deprecation.py:323] From <ipython-input-1-ac654c5da435>:20: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W1212 14:33:38.512109  3456 deprecation.py:323] From C:\Users\Laboratory\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# training start!
# [1/100] - ptime: 8.02 loss_d: 0.766, loss_g: 1.111
# [2/100] - ptime: 10.52 loss_d: 0.453, loss_g: 1.918
# [3/100] - ptime: 9.43 loss_d: 0.646, loss_g: 1.750
# [4/100] - ptime: 9.59 loss_d: 0.614, loss_g: 1.862
# [5/100] - ptime: 11.11 loss_d: 0.658, loss_g: 1.795
# [6/100] - ptime: 8.87 loss_d: 0.750, loss_g: 1.636
# [7/100] - ptime: 8.07 loss_d: 0.676, loss_g: 1.759
# [8/100] - ptime: 8.65 loss_d: 0.649, loss_g: 1.948
# [9/100] - ptime: 9.21 loss_d: 0.637, loss_g: 2.043
# [10/100] - ptime: 8.10 loss_d: 0.603, loss_g: 2.206
# [11/100] - ptime: 8.66 loss_d: 0.601, loss_g: 2.258
# [12/100] - ptime: 7.48 loss_d: 0.597, loss_g: 2.271
# [13/100] - ptime: 9.40 loss_d: 0.606, loss_g: 2.283
# [14/100] - ptime: 10.34 loss_d: 0.635, loss_g: 2.250
# [15/100] - ptime: 8.41 loss_d: 0.644, loss_g: 2.210
# [16/100] - ptime: 8.15 loss_d: 0.625, loss_g: 2.217
# [17/100] - ptime: 8.13 loss_d: 0.640, loss_g: 2.213
# [18/100] - ptime: 7.46 loss_d: 0.664, loss_g: 2.135
# [19/100] - ptime: 7.76 loss_d: 0.680, loss_g: 2.086
# [20/100] - ptime: 9.60 loss_d: 0.697, loss_g: 2.047
# [21/100] - ptime: 9.37 loss_d: 0.731, loss_g: 1.970
# [22/100] - ptime: 8.77 loss_d: 0.756, loss_g: 1.868
# [23/100] - ptime: 8.70 loss_d: 0.797, loss_g: 1.769
# [24/100] - ptime: 7.57 loss_d: 0.819, loss_g: 1.678
# [25/100] - ptime: 7.99 loss_d: 0.853, loss_g: 1.583
# [26/100] - ptime: 8.69 loss_d: 0.882, loss_g: 1.533
# [27/100] - ptime: 7.80 loss_d: 0.885, loss_g: 1.508
# [28/100] - ptime: 7.71 loss_d: 0.875, loss_g: 1.490
# [29/100] - ptime: 8.32 loss_d: 0.893, loss_g: 1.456
# [30/100] - ptime: 8.81 loss_d: 0.899, loss_g: 1.419
# [31/100] - ptime: 8.32 loss_d: 0.924, loss_g: 1.400
# [32/100] - ptime: 7.46 loss_d: 0.923, loss_g: 1.406
# [33/100] - ptime: 7.41 loss_d: 0.891, loss_g: 1.420
# [34/100] - ptime: 7.29 loss_d: 0.907, loss_g: 1.415
# [35/100] - ptime: 8.30 loss_d: 0.906, loss_g: 1.411
# [36/100] - ptime: 8.37 loss_d: 0.917, loss_g: 1.389
# [37/100] - ptime: 9.21 loss_d: 0.905, loss_g: 1.401
# [38/100] - ptime: 9.31 loss_d: 0.925, loss_g: 1.379
# [39/100] - ptime: 7.43 loss_d: 0.939, loss_g: 1.357
# [40/100] - ptime: 7.65 loss_d: 0.925, loss_g: 1.372
# [41/100] - ptime: 9.35 loss_d: 0.934, loss_g: 1.357
# [42/100] - ptime: 7.58 loss_d: 0.934, loss_g: 1.368
# [43/100] - ptime: 7.44 loss_d: 0.944, loss_g: 1.360
# [44/100] - ptime: 7.28 loss_d: 0.945, loss_g: 1.350
# [45/100] - ptime: 7.43 loss_d: 0.942, loss_g: 1.342
# [46/100] - ptime: 7.52 loss_d: 0.947, loss_g: 1.336
# [47/100] - ptime: 8.08 loss_d: 0.961, loss_g: 1.336
# [48/100] - ptime: 7.99 loss_d: 0.957, loss_g: 1.335
# [49/100] - ptime: 7.34 loss_d: 0.960, loss_g: 1.341
# [50/100] - ptime: 6.91 loss_d: 0.967, loss_g: 1.328
# [51/100] - ptime: 7.28 loss_d: 0.988, loss_g: 1.291
# [52/100] - ptime: 7.24 loss_d: 0.988, loss_g: 1.294
# [53/100] - ptime: 6.94 loss_d: 0.984, loss_g: 1.277
# [54/100] - ptime: 6.97 loss_d: 0.987, loss_g: 1.263
# [55/100] - ptime: 6.95 loss_d: 0.983, loss_g: 1.284
# [56/100] - ptime: 6.88 loss_d: 0.988, loss_g: 1.274
# [57/100] - ptime: 6.89 loss_d: 0.990, loss_g: 1.274
# [58/100] - ptime: 6.96 loss_d: 0.983, loss_g: 1.279
# [59/100] - ptime: 6.91 loss_d: 1.002, loss_g: 1.246
# [60/100] - ptime: 6.94 loss_d: 1.010, loss_g: 1.233
# [61/100] - ptime: 6.89 loss_d: 1.012, loss_g: 1.244
# [62/100] - ptime: 6.90 loss_d: 1.004, loss_g: 1.243
# [63/100] - ptime: 6.97 loss_d: 1.012, loss_g: 1.224
# [64/100] - ptime: 6.90 loss_d: 1.003, loss_g: 1.230
# [65/100] - ptime: 6.97 loss_d: 1.001, loss_g: 1.235
# [66/100] - ptime: 6.97 loss_d: 1.011, loss_g: 1.218
# [67/100] - ptime: 7.14 loss_d: 1.014, loss_g: 1.221
# [68/100] - ptime: 7.26 loss_d: 1.018, loss_g: 1.221
# [69/100] - ptime: 7.21 loss_d: 1.018, loss_g: 1.216
# [70/100] - ptime: 7.05 loss_d: 1.026, loss_g: 1.208
# [71/100] - ptime: 7.38 loss_d: 1.030, loss_g: 1.204
# [72/100] - ptime: 7.04 loss_d: 1.029, loss_g: 1.203
# [73/100] - ptime: 6.96 loss_d: 1.037, loss_g: 1.182
# [74/100] - ptime: 7.00 loss_d: 1.038, loss_g: 1.182
# [75/100] - ptime: 6.96 loss_d: 1.033, loss_g: 1.185
# [76/100] - ptime: 7.01 loss_d: 1.027, loss_g: 1.179
# [77/100] - ptime: 7.12 loss_d: 1.026, loss_g: 1.178
# [78/100] - ptime: 6.97 loss_d: 1.034, loss_g: 1.182
# [79/100] - ptime: 7.03 loss_d: 1.046, loss_g: 1.166
# [80/100] - ptime: 6.99 loss_d: 1.050, loss_g: 1.165
# [81/100] - ptime: 7.09 loss_d: 1.051, loss_g: 1.160
# [82/100] - ptime: 7.13 loss_d: 1.055, loss_g: 1.149
# [83/100] - ptime: 6.98 loss_d: 1.059, loss_g: 1.150
# [84/100] - ptime: 7.06 loss_d: 1.063, loss_g: 1.148
# [85/100] - ptime: 7.00 loss_d: 1.056, loss_g: 1.158
# [86/100] - ptime: 7.00 loss_d: 1.055, loss_g: 1.152
# [87/100] - ptime: 7.02 loss_d: 1.060, loss_g: 1.146
# [88/100] - ptime: 7.06 loss_d: 1.060, loss_g: 1.143
# [89/100] - ptime: 7.00 loss_d: 1.067, loss_g: 1.141
# [90/100] - ptime: 7.09 loss_d: 1.062, loss_g: 1.146
# [91/100] - ptime: 7.15 loss_d: 1.065, loss_g: 1.131
# [92/100] - ptime: 7.10 loss_d: 1.073, loss_g: 1.132
# [93/100] - ptime: 7.15 loss_d: 1.066, loss_g: 1.126
# [94/100] - ptime: 7.08 loss_d: 1.061, loss_g: 1.121
# [95/100] - ptime: 7.02 loss_d: 1.063, loss_g: 1.124
# [96/100] - ptime: 7.07 loss_d: 1.069, loss_g: 1.121
# [97/100] - ptime: 7.08 loss_d: 1.065, loss_g: 1.115
# [98/100] - ptime: 7.10 loss_d: 1.072, loss_g: 1.114
# [99/100] - ptime: 7.05 loss_d: 1.068, loss_g: 1.119
# [100/100] - ptime: 7.23 loss_d: 1.074, loss_g: 1.118
# Avg per epoch ptime: 7.70, total 100 epochs ptime: 1287.83
# Training finish!... save training results
